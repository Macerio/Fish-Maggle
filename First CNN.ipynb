# %%
import os, pickle
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


from keras.models import Sequential
from keras.layers import Activation, Convolution2D, Dense, Dropout, Flatten, MaxPooling2D
from keras.preprocessing.image import array_to_img, img_to_array, load_img
from keras.utils import np_utils

from sklearn.metrics import log_loss
from sklearn.cross_validation import train_test_split
from sklearn.utils.class_weight import compute_class_weight
import operator

from subprocess import check_output
# print(check_output(["ls", "../input"]).decode("utf8"))

# Any results you write to the current directory are saved as output.

# %%
os.chdir('/Users/HUGO/Documents/Kaggle/FISH/input')

# %%
os.listdir(os.path.join('../input/train', d))
# Out:
# ['.DS_Store',
#  'img_00003.jpg',
#  'img_00010.jpg',
#  'img_00012.jpg',
#  'img_00015.jpg',
#  'img_00019.jpg',
#  'img_00020.jpg',
#  'img_00029.jpg',
#  'img_00032.jpg',
#  'img_00037.jpg',
#  'img_00038.jpg',
#  'img_00039.jpg',
#  'img_00041.jpg',
#  'img_00043.jpg',
#  'img_00045.jpg',
#  'img_00055.jpg',
#  'img_00057.jpg',
#  'img_00074.jpg',
#  'img_00085.jpg',
#  'img_00090.jpg',
#  'img_00097.jpg',
#  'img_00110.jpg',
#  'img_00121.jpg',
#  'img_00130.jpg',
#  'img_00134.jpg',
#  'img_00136.jpg',
#  'img_00154.jpg',
#  'img_00156.jpg',
#  'img_00163.jpg',
#  'img_00177.jpg',
#  'img_00186.jpg',
#  'img_00187.jpg',
#  'img_00188.jpg',
#  'img_00191.jpg',
#  'img_00193.jpg',
#  'img_00197.jpg',
#  'img_00201.jpg',
#  'img_00206.jpg',
#  'img_00208.jpg',
#  'img_00209.jpg',
#  'img_00211.jpg',
#  'img_00215.jpg',
#  'img_00219.jpg',
#  'img_00227.jpg',
#  'img_00228.jpg',
#  'img_00233.jpg',
#  'img_00236.jpg',
#  'img_00237.jpg',
#  'img_00239.jpg',
#  'img_00248.jpg',
#  'img_00264.jpg',
#  'img_00269.jpg',
#  'img_00270.jpg',
#  'img_00274.jpg',
#  'img_00275.jpg',
#  'img_00277.jpg',
#  'img_00278.jpg',
#  'img_00281.jpg',
#  'img_00288.jpg',
#  'img_00290.jpg',
#  'img_00291.jpg',
#  'img_00294.jpg',
#  'img_00295.jpg',
#  'img_00296.jpg',
#  'img_00299.jpg',
#  'img_00300.jpg',
#  'img_00301.jpg',
#  'img_00317.jpg',
#  'img_00319.jpg',
#  'img_00327.jpg',
#  'img_00337.jpg',
#  'img_00338.jpg',
#  'img_00341.jpg',
#  'img_00342.jpg',
#  'img_00344.jpg',
#  'img_00351.jpg',
#  'img_00353.jpg',
#  'img_00356.jpg',
#  'img_00361.jpg',
#  'img_00366.jpg',
#  'img_00369.jpg',
#  'img_00381.jpg',
#  'img_00384.jpg',
#  'img_00385.jpg',
#  'img_00396.jpg',
#  'img_00401.jpg',
#  'img_00403.jpg',
#  'img_00415.jpg',
#  'img_00421.jpg',
#  'img_00425.jpg',
#  'img_00447.jpg',
#  'img_00451.jpg',
#  'img_00457.jpg',
#  'img_00461.jpg',
#  'img_00466.jpg',
#  'img_00482.jpg',
#  'img_00490.jpg',
#  'img_00496.jpg',
#  'img_00502.jpg',
#  'img_00507.jpg',
#  'img_00508.jpg',
#  'img_00509.jpg',
#  'img_00523.jpg',
#  'img_00525.jpg',
#  'img_00526.jpg',
#  'img_00544.jpg',
#  'img_00545.jpg',
#  'img_00546.jpg',
#  'img_00555.jpg',
#  'img_00558.jpg',
#  'img_00561.jpg',
#  'img_00562.jpg',
#  'img_00568.jpg',
#  'img_00570.jpg',
#  'img_00576.jpg',
#  'img_00579.jpg',
#  'img_00592.jpg',
#  'img_00594.jpg',
#  'img_00595.jpg',
#  'img_00596.jpg',
#  'img_00605.jpg',
#  'img_00607.jpg',
#  'img_00617.jpg',
#  'img_00624.jpg',
#  'img_00626.jpg',
#  'img_00632.jpg',
#  'img_00633.jpg',
#  'img_00634.jpg',
#  'img_00636.jpg',
#  'img_00638.jpg',
#  'img_00643.jpg',
#  'img_00653.jpg',
#  'img_00660.jpg',
#  'img_00665.jpg',
#  'img_00668.jpg',
#  'img_00672.jpg',
#  'img_00679.jpg',
#  'img_00684.jpg',
#  'img_00687.jpg',
#  'img_00690.jpg',
#  'img_00701.jpg',
#  'img_00705.jpg',
#  'img_00706.jpg',
#  'img_00710.jpg',
#  'img_00712.jpg',
#  'img_00713.jpg',
#  'img_00714.jpg',
#  'img_00715.jpg',
#  'img_00719.jpg',
#  'img_00722.jpg',
#  'img_00727.jpg',
#  'img_00728.jpg',
#  'img_00741.jpg',
#  'img_00742.jpg',
#  'img_00744.jpg',
#  'img_00745.jpg',
#  'img_00747.jpg',
#  'img_00754.jpg',
#  'img_00756.jpg',
#  'img_00762.jpg',
#  'img_00782.jpg',
#  'img_00788.jpg',
#  'img_00790.jpg',
#  'img_00793.jpg',
#  'img_00809.jpg',
#  'img_00810.jpg',
#  'img_00811.jpg',
#  'img_00817.jpg',
#  'img_00820.jpg',
#  'img_00823.jpg',
#  'img_00824.jpg',
#  'img_00829.jpg',
#  'img_00831.jpg',
#  'img_00834.jpg',
#  'img_00840.jpg',
#  'img_00843.jpg',
#  'img_00863.jpg',
#  'img_00866.jpg',
#  'img_00869.jpg',
#  'img_00870.jpg',
#  'img_00878.jpg',
#  'img_00880.jpg',
#  'img_00881.jpg',
#  'img_00885.jpg',
#  'img_00893.jpg',
#  'img_00895.jpg',
#  'img_00897.jpg',
#  'img_00898.jpg',
#  'img_00899.jpg',
#  'img_00901.jpg',
#  'img_00911.jpg',
#  'img_00928.jpg',
#  'img_00939.jpg',
#  'img_00940.jpg',
#  'img_00956.jpg',
#  'img_00957.jpg',
#  'img_00961.jpg',
#  'img_00967.jpg',
#  'img_00970.jpg',
#  'img_00975.jpg',
#  'img_00984.jpg',
#  'img_00987.jpg',
#  'img_00993.jpg',
#  'img_00994.jpg',
#  'img_00996.jpg',
#  'img_00998.jpg',
#  'img_01000.jpg',
#  'img_01001.jpg',
#  'img_01006.jpg',
#  'img_01009.jpg',
#  'img_01011.jpg',
#  'img_01014.jpg',
#  'img_01021.jpg',
#  'img_01023.jpg',
#  'img_01025.jpg',
#  'img_01028.jpg',
#  'img_01029.jpg',
#  'img_01032.jpg',
#  'img_01033.jpg',
#  'img_01038.jpg',
#  'img_01045.jpg',
#  'img_01046.jpg',
#  'img_01047.jpg',
#  'img_01056.jpg',
#  'img_01063.jpg',
#  'img_01066.jpg',
#  'img_01070.jpg',
#  'img_01072.jpg',
#  'img_01074.jpg',
#  'img_01077.jpg',
#  'img_01079.jpg',
#  'img_01082.jpg',
#  'img_01083.jpg',
#  'img_01085.jpg',
#  'img_01086.jpg',
#  'img_01093.jpg',
#  'img_01095.jpg',
#  'img_01105.jpg',
#  'img_01109.jpg',
#  'img_01110.jpg',
#  'img_01111.jpg',
#  'img_01112.jpg',
#  'img_01117.jpg',
#  'img_01121.jpg',
#  'img_01125.jpg',
#  'img_01127.jpg',
#  'img_01128.jpg',
#  'img_01129.jpg',
#  'img_01130.jpg',
#  'img_01139.jpg',
#  'img_01141.jpg',
#  'img_01144.jpg',
#  'img_01152.jpg',
#  'img_01160.jpg',
#  'img_01162.jpg',
#  'img_01163.jpg',
#  'img_01183.jpg',
#  'img_01186.jpg',
#  'img_01191.jpg',
#  'img_01196.jpg',
#  'img_01197.jpg',
#  'img_01205.jpg',
#  'img_01206.jpg',
#  'img_01207.jpg',
#  'img_01225.jpg',
#  'img_01238.jpg',
#  'img_01239.jpg',
#  'img_01240.jpg',
#  'img_01243.jpg',
#  'img_01246.jpg',
#  'img_01247.jpg',
#  'img_01255.jpg',
#  'img_01261.jpg',
#  'img_01262.jpg',
#  'img_01265.jpg',
#  'img_01268.jpg',
#  'img_01271.jpg',
#  'img_01273.jpg',
#  'img_01276.jpg',
#  'img_01278.jpg',
#  'img_01282.jpg',
#  'img_01287.jpg',
#  'img_01291.jpg',
#  'img_01300.jpg',
#  'img_01304.jpg',
#  'img_01306.jpg',
#  'img_01313.jpg',
#  'img_01314.jpg',
#  'img_01316.jpg',
#  'img_01319.jpg',
#  'img_01330.jpg',
#  'img_01333.jpg',
#  'img_01334.jpg',
#  'img_01336.jpg',
#  'img_01338.jpg',
#  'img_01353.jpg',
#  'img_01354.jpg',
#  'img_01355.jpg',
#  'img_01357.jpg',
#  'img_01361.jpg',
#  'img_01362.jpg',
#  'img_01363.jpg',
#  'img_01364.jpg',
#  'img_01367.jpg',
#  'img_01374.jpg',
#  'img_01390.jpg',
#  'img_01396.jpg',
#  'img_01398.jpg',
#  'img_01401.jpg',
#  'img_01402.jpg',
#  'img_01409.jpg',
#  'img_01416.jpg',
#  'img_01417.jpg',
#  'img_01422.jpg',
#  'img_01433.jpg',
#  'img_01434.jpg',
#  'img_01445.jpg',
#  'img_01446.jpg',
#  'img_01448.jpg',
#  'img_01454.jpg',
#  'img_01455.jpg',
#  'img_01458.jpg',
#  'img_01460.jpg',
#  'img_01464.jpg',
#  'img_01466.jpg',
#  'img_01478.jpg',
#  'img_01480.jpg',
#  'img_01482.jpg',
#  'img_01485.jpg',
#  'img_01489.jpg',
#  'img_01506.jpg',
#  'img_01507.jpg',
#  'img_01509.jpg',
#  'img_01514.jpg',
#  'img_01520.jpg',
#  'img_01529.jpg',
#  'img_01540.jpg',
#  'img_01542.jpg',
#  'img_01547.jpg',
#  'img_01554.jpg',
#  'img_01556.jpg',
#  'img_01558.jpg',
#  'img_01570.jpg',
#  'img_01574.jpg',
#  'img_01578.jpg',
#  'img_01580.jpg',
#  'img_01584.jpg',
#  'img_01590.jpg',
#  'img_01599.jpg',
#  'img_01601.jpg',
#  'img_01603.jpg',
#  'img_01604.jpg',
#  'img_01607.jpg',
#  'img_01612.jpg',
#  'img_01620.jpg',
#  'img_01636.jpg',
#  'img_01638.jpg',
#  'img_01641.jpg',
#  'img_01645.jpg',
#  'img_01652.jpg',
#  'img_01654.jpg',
#  'img_01655.jpg',
#  'img_01660.jpg',
#  'img_01663.jpg',
#  'img_01680.jpg',
#  'img_01682.jpg',
#  'img_01683.jpg',
#  'img_01686.jpg',
#  'img_01690.jpg',
#  'img_01693.jpg',
#  'img_01699.jpg',
#  'img_01713.jpg',
#  'img_01722.jpg',
#  'img_01728.jpg',
#  'img_01729.jpg',
#  'img_01733.jpg',
#  'img_01734.jpg',
#  'img_01735.jpg',
#  'img_01738.jpg',
#  'img_01741.jpg',
#  'img_01744.jpg',
#  'img_01753.jpg',
#  'img_01756.jpg',
#  'img_01763.jpg',
#  'img_01768.jpg',
#  'img_01772.jpg',
#  'img_01778.jpg',
#  'img_01786.jpg',
#  'img_01788.jpg',
#  'img_01790.jpg',
#  'img_01796.jpg',
#  'img_01797.jpg',
#  'img_01800.jpg',
#  'img_01804.jpg',
#  'img_01805.jpg',
#  'img_01806.jpg',
#  'img_01809.jpg',
#  'img_01810.jpg',
#  'img_01816.jpg',
#  'img_01819.jpg',
#  'img_01822.jpg',
#  'img_01823.jpg',
#  'img_01826.jpg',
#  'img_01830.jpg',
#  'img_01833.jpg',
#  'img_01838.jpg',
#  'img_01841.jpg',
#  'img_01846.jpg',
#  'img_01855.jpg',
#  'img_01858.jpg',
#  'img_01865.jpg',
#  'img_01869.jpg',
#  'img_01875.jpg',
#  'img_01878.jpg',
#  'img_01883.jpg',
#  'img_01884.jpg',
#  'img_01890.jpg',
#  'img_01896.jpg',
#  'img_01897.jpg',
#  'img_01901.jpg',
#  'img_01902.jpg',
#  'img_01909.jpg',
#  'img_01910.jpg',
#  'img_01911.jpg',
#  'img_01914.jpg',
#  'img_01917.jpg',
#  'img_01919.jpg',
#  'img_01921.jpg',
#  'img_01926.jpg',
#  'img_01928.jpg',
#  'img_01929.jpg',
#  'img_01931.jpg',
#  'img_01934.jpg',
#  'img_01936.jpg',
#  'img_01941.jpg',
#  'img_01948.jpg',
#  'img_01949.jpg',
#  'img_01950.jpg',
#  'img_01954.jpg',
#  'img_01958.jpg',
#  'img_01975.jpg',
#  'img_01980.jpg',
#  'img_01985.jpg',
#  'img_01990.jpg',
#  'img_01992.jpg',
#  'img_02002.jpg',
#  'img_02005.jpg',
#  'img_02008.jpg',
#  'img_02012.jpg',
#  'img_02018.jpg',
#  'img_02019.jpg',
#  'img_02025.jpg',
#  'img_02030.jpg',
#  'img_02032.jpg',
#  'img_02034.jpg',
#  'img_02035.jpg',
#  'img_02036.jpg',
#  'img_02039.jpg',
#  'img_02046.jpg',
#  'img_02047.jpg',
#  'img_02052.jpg',
#  'img_02058.jpg',
#  'img_02063.jpg',
#  'img_02068.jpg',
#  'img_02069.jpg',
#  'img_02072.jpg',
#  'img_02086.jpg',
#  'img_02090.jpg',
#  'img_02106.jpg',
#  'img_02107.jpg',
#  'img_02108.jpg',
#  'img_02109.jpg',
#  'img_02112.jpg',
#  'img_02118.jpg',
#  'img_02120.jpg',
#  'img_02133.jpg',
#  'img_02134.jpg',
#  'img_02140.jpg',
#  'img_02148.jpg',
#  'img_02151.jpg',
#  'img_02163.jpg',
#  'img_02170.jpg',
#  'img_02171.jpg',
#  'img_02174.jpg',
#  'img_02178.jpg',
#  'img_02182.jpg',
#  'img_02184.jpg',
#  'img_02185.jpg',
#  'img_02189.jpg',
#  'img_02190.jpg',
#  'img_02192.jpg',
#  'img_02197.jpg',
#  'img_02201.jpg',
#  'img_02203.jpg',
#  'img_02205.jpg',
#  'img_02208.jpg',
#  'img_02227.jpg',
#  'img_02229.jpg',
#  'img_02250.jpg',
#  'img_02253.jpg',
#  'img_02254.jpg',
#  'img_02263.jpg',
#  'img_02273.jpg',
#  'img_02276.jpg',
#  'img_02283.jpg',
#  'img_02286.jpg',
#  'img_02289.jpg',
#  'img_02292.jpg',
#  'img_02296.jpg',
#  'img_02324.jpg',
#  'img_02326.jpg',
#  'img_02328.jpg',
#  'img_02338.jpg',
#  'img_02340.jpg',
#  'img_02342.jpg',
#  'img_02346.jpg',
#  'img_02352.jpg',
#  'img_02359.jpg',
#  'img_02361.jpg',
#  'img_02362.jpg',
#  'img_02373.jpg',
#  'img_02376.jpg',
#  'img_02382.jpg',
#  'img_02386.jpg',
#  'img_02388.jpg',
#  'img_02392.jpg',
#  'img_02393.jpg',
#  'img_02396.jpg',
#  'img_02399.jpg',
#  'img_02404.jpg',
#  'img_02405.jpg',
#  'img_02408.jpg',
#  'img_02410.jpg',
#  'img_02414.jpg',
#  'img_02418.jpg',
#  'img_02420.jpg',
#  'img_02421.jpg',
#  'img_02425.jpg',
#  'img_02433.jpg',
#  'img_02436.jpg',
#  'img_02437.jpg',
#  'img_02446.jpg',
#  'img_02447.jpg',
#  'img_02448.jpg',
#  'img_02452.jpg',
#  'img_02453.jpg',
#  'img_02456.jpg',
#  'img_02468.jpg',
#  'img_02470.jpg',
#  'img_02471.jpg',
#  'img_02477.jpg',
#  'img_02480.jpg',
#  'img_02481.jpg',
#  'img_02484.jpg',
#  'img_02488.jpg',
#  'img_02489.jpg',
#  'img_02491.jpg',
#  'img_02492.jpg',
#  'img_02494.jpg',
#  'img_02495.jpg',
#  'img_02499.jpg',
#  'img_02501.jpg',
#  'img_02513.jpg',
#  'img_02514.jpg',
#  'img_02519.jpg',
#  'img_02530.jpg',
#  'img_02537.jpg',
#  'img_02542.jpg',
#  'img_02545.jpg',
#  'img_02547.jpg',
#  'img_02549.jpg',
#  'img_02551.jpg',
#  'img_02555.jpg',
#  'img_02572.jpg',
#  'img_02576.jpg',
#  'img_02578.jpg',
#  'img_02583.jpg',
#  'img_02584.jpg',
#  'img_02586.jpg',
#  'img_02591.jpg',
#  'img_02593.jpg',
#  'img_02604.jpg',
#  'img_02605.jpg',
#  'img_02609.jpg',
#  'img_02610.jpg',
#  'img_02623.jpg',
#  'img_02629.jpg',
#  'img_02630.jpg',
#  'img_02635.jpg',
#  'img_02643.jpg',
#  'img_02645.jpg',
#  'img_02658.jpg',
#  'img_02662.jpg',
#  'img_02664.jpg',
#  'img_02671.jpg',
#  'img_02686.jpg',
#  'img_02689.jpg',
#  'img_02695.jpg',
#  'img_02698.jpg',
#  'img_02704.jpg',
#  'img_02710.jpg',
#  'img_02719.jpg',
#  'img_02724.jpg',
#  'img_02725.jpg',
#  'img_02729.jpg',
#  'img_02737.jpg',
#  'img_02762.jpg',
#  'img_02765.jpg',
#  'img_02768.jpg',
#  'img_02774.jpg',
#  'img_02776.jpg',
#  'img_02777.jpg',
#  'img_02779.jpg',
#  'img_02784.jpg',
#  'img_02793.jpg',
#  'img_02794.jpg',
#  'img_02801.jpg',
#  'img_02807.jpg',
#  'img_02816.jpg',
#  'img_02820.jpg',
#  'img_02821.jpg',
#  'img_02823.jpg',
#  'img_02825.jpg',
#  'img_02828.jpg',
#  'img_02856.jpg',
#  'img_02859.jpg',
#  'img_02862.jpg',
#  'img_02868.jpg',
#  'img_02875.jpg',
#  'img_02880.jpg',
#  'img_02883.jpg',
#  'img_02885.jpg',
#  'img_02886.jpg',
#  'img_02888.jpg',
#  'img_02901.jpg',
#  'img_02913.jpg',
#  'img_02915.jpg',
#  'img_02925.jpg',
#  'img_02928.jpg',
#  'img_02931.jpg',
#  'img_02933.jpg',
#  'img_02938.jpg',
#  'img_02940.jpg',
#  'img_02945.jpg',
#  'img_02946.jpg',
#  'img_02948.jpg',
#  'img_02950.jpg',
#  'img_02978.jpg',
#  'img_02992.jpg',
#  'img_02994.jpg',
#  'img_02995.jpg',
#  'img_02996.jpg',
#  'img_03003.jpg',
#  'img_03005.jpg',
#  'img_03011.jpg',
#  'img_03016.jpg',
#  'img_03017.jpg',
#  'img_03021.jpg',
#  'img_03031.jpg',
#  'img_03037.jpg',
#  'img_03038.jpg',
#  'img_03039.jpg',
#  'img_03040.jpg',
#  'img_03041.jpg',
#  'img_03047.jpg',
#  'img_03050.jpg',
#  'img_03061.jpg',
#  'img_03067.jpg',
#  'img_03089.jpg',
#  'img_03090.jpg',
#  'img_03092.jpg',
#  'img_03099.jpg',
#  'img_03106.jpg',
#  'img_03107.jpg',
#  'img_03108.jpg',
#  'img_03112.jpg',
#  'img_03115.jpg',
#  'img_03119.jpg',
#  'img_03123.jpg',
#  'img_03125.jpg',
#  'img_03141.jpg',
#  'img_03143.jpg',
#  'img_03145.jpg',
#  'img_03146.jpg',
#  'img_03147.jpg',
#  'img_03150.jpg',
#  'img_03151.jpg',
#  'img_03153.jpg',
#  'img_03154.jpg',
#  'img_03159.jpg',
#  'img_03161.jpg',
#  'img_03164.jpg',
#  'img_03171.jpg',
#  'img_03176.jpg',
#  'img_03179.jpg',
#  'img_03182.jpg',
#  'img_03188.jpg',
#  'img_03202.jpg',
#  'img_03208.jpg',
#  'img_03209.jpg',
#  'img_03212.jpg',
#  'img_03213.jpg',
#  'img_03215.jpg',
#  'img_03216.jpg',
#  'img_03224.jpg',
#  'img_03226.jpg',
#  'img_03233.jpg',
#  'img_03237.jpg',
#  'img_03250.jpg',
#  'img_03251.jpg',
#  'img_03262.jpg',
#  'img_03263.jpg',
#  'img_03264.jpg',
#  'img_03277.jpg',
#  'img_03281.jpg',
#  'img_03282.jpg',
#  'img_03286.jpg',
#  'img_03293.jpg',
#  'img_03300.jpg',
#  'img_03304.jpg',
#  'img_03307.jpg',
#  'img_03311.jpg',
#  'img_03314.jpg',
#  'img_03320.jpg',
#  'img_03323.jpg',
#  'img_03335.jpg',
#  'img_03341.jpg',
#  'img_03344.jpg',
#  'img_03345.jpg',
#  'img_03348.jpg',
#  'img_03350.jpg',
#  'img_03352.jpg',
#  'img_03356.jpg',
#  'img_03357.jpg',
#  'img_03360.jpg',
#  'img_03363.jpg',
#  'img_03369.jpg',
#  'img_03373.jpg',
#  'img_03374.jpg',
#  'img_03376.jpg',
#  'img_03381.jpg',
#  'img_03382.jpg',
#  'img_03384.jpg',
#  'img_03387.jpg',
#  'img_03391.jpg',
#  'img_03397.jpg',
#  'img_03401.jpg',
#  'img_03406.jpg',
#  'img_03411.jpg',
#  'img_03414.jpg',
#  'img_03424.jpg',
#  'img_03427.jpg',
#  'img_03429.jpg',
#  'img_03431.jpg',
#  'img_03432.jpg',
#  'img_03448.jpg',
#  'img_03451.jpg',
#  'img_03458.jpg',
#  'img_03463.jpg',
#  'img_03466.jpg',
#  'img_03470.jpg',
#  'img_03479.jpg',
#  'img_03482.jpg',
#  'img_03483.jpg',
#  'img_03486.jpg',
#  'img_03487.jpg',
#  'img_03491.jpg',
#  'img_03499.jpg',
#  'img_03501.jpg',
#  'img_03509.jpg',
#  'img_03512.jpg',
#  'img_03515.jpg',
#  'img_03516.jpg',
#  'img_03524.jpg',
#  'img_03532.jpg',
#  'img_03535.jpg',
#  'img_03538.jpg',
#  'img_03544.jpg',
#  'img_03549.jpg',
#  'img_03552.jpg',
#  'img_03553.jpg',
#  'img_03556.jpg',
#  'img_03559.jpg',
#  'img_03569.jpg',
#  'img_03570.jpg',
#  'img_03575.jpg',
#  'img_03576.jpg',
#  'img_03578.jpg',
#  'img_03579.jpg',
#  'img_03586.jpg',
#  'img_03589.jpg',
#  'img_03593.jpg',
#  'img_03599.jpg',
#  'img_03600.jpg',
#  'img_03603.jpg',
#  'img_03606.jpg',
#  'img_03612.jpg',
#  'img_03616.jpg',
#  'img_03620.jpg',
#  'img_03623.jpg',
#  'img_03625.jpg',
#  'img_03634.jpg',
#  'img_03635.jpg',
#  'img_03636.jpg',
#  'img_03642.jpg',
#  'img_03644.jpg',
#  'img_03645.jpg',
#  'img_03656.jpg',
#  'img_03661.jpg',
#  'img_03662.jpg',
#  'img_03664.jpg',
#  'img_03666.jpg',
#  'img_03673.jpg',
#  'img_03680.jpg',
#  'img_03682.jpg',
#  'img_03686.jpg',
#  'img_03687.jpg',
#  'img_03693.jpg',
#  'img_03694.jpg',
#  'img_03698.jpg',
#  'img_03699.jpg',
#  'img_03700.jpg',
#  'img_03706.jpg',
#  'img_03709.jpg',
#  'img_03713.jpg',
#  'img_03714.jpg',
#  'img_03729.jpg',
#  'img_03730.jpg',
#  'img_03736.jpg',
#  'img_03737.jpg',
#  'img_03738.jpg',
#  'img_03746.jpg',
#  'img_03747.jpg',
#  'img_03748.jpg',
#  'img_03758.jpg',
#  'img_03775.jpg',
#  'img_03780.jpg',
#  'img_03785.jpg',
#  'img_03793.jpg',
#  'img_03794.jpg',
#  'img_03797.jpg',
#  'img_03798.jpg',
#  'img_03800.jpg',
#  'img_03808.jpg',
#  'img_03820.jpg',
#  'img_03821.jpg',
#  'img_03827.jpg',
#  'img_03836.jpg',
#  'img_03842.jpg',
#  'img_03845.jpg',
#  'img_03851.jpg',
#  'img_03855.jpg',
#  'img_03858.jpg',
#  'img_03859.jpg',
#  'img_03860.jpg',
#  'img_03861.jpg',
#  'img_03862.jpg',
#  'img_03877.jpg',
#  'img_03879.jpg',
#  'img_03880.jpg',
#  'img_03884.jpg',
#  'img_03902.jpg',
#  'img_03904.jpg',
#  'img_03905.jpg',
#  'img_03910.jpg',
#  'img_03913.jpg',
#  'img_03927.jpg',
#  'img_03932.jpg',
#  'img_03944.jpg',
#  'img_03965.jpg',
#  'img_03969.jpg',
#  'img_03984.jpg',
#  'img_03985.jpg',
#  'img_03990.jpg',
#  'img_03991.jpg',
#  'img_04005.jpg',
#  'img_04006.jpg',
#  'img_04008.jpg',
#  'img_04011.jpg',
#  'img_04014.jpg',
#  'img_04016.jpg',
#  'img_04018.jpg',
#  'img_04023.jpg',
#  'img_04025.jpg',
#  'img_04026.jpg',
#  'img_04031.jpg',
#  'img_04032.jpg',
#  'img_04040.jpg',
#  'img_04043.jpg',
#  'img_04054.jpg',
#  'img_04055.jpg',
#  'img_04056.jpg',
#  'img_04059.jpg',
#  'img_04062.jpg',
#  'img_04065.jpg',
#  'img_04070.jpg',
#  'img_04075.jpg',
#  'img_04078.jpg',
#  'img_04086.jpg',
#  'img_04090.jpg',
#  'img_04092.jpg',
#  'img_04093.jpg',
#  'img_04098.jpg',
#  'img_04100.jpg',
#  'img_04102.jpg',
#  'img_04112.jpg',
#  'img_04121.jpg',
#  'img_04124.jpg',
#  'img_04140.jpg',
#  'img_04147.jpg',
#  'img_04153.jpg',
#  'img_04154.jpg',
#  'img_04163.jpg',
#  'img_04164.jpg',
#  'img_04174.jpg',
#  'img_04187.jpg',
#  'img_04196.jpg',
#  'img_04202.jpg',
#  'img_04205.jpg',
#  'img_04206.jpg',
#  'img_04220.jpg',
#  'img_04229.jpg',
#  'img_04231.jpg',
#  'img_04243.jpg',
#  'img_04248.jpg',
#  'img_04259.jpg',
#  'img_04277.jpg',
#  'img_04290.jpg',
#  'img_04296.jpg',
#  'img_04301.jpg',
#  'img_04303.jpg',
#  'img_04307.jpg',
#  'img_04308.jpg',
#  'img_04309.jpg',
#  'img_04312.jpg',
#  'img_04320.jpg',
#  'img_04326.jpg',
#  'img_04330.jpg',
#  'img_04336.jpg',
#  'img_04340.jpg',
#  'img_04342.jpg',
#  'img_04345.jpg',
#  'img_04346.jpg',
#  'img_04347.jpg',
#  'img_04349.jpg',
#  'img_04350.jpg',
#  'img_04354.jpg',
#  'img_04361.jpg',
#  'img_04362.jpg',
#  'img_04368.jpg',
#  'img_04377.jpg',
#  'img_04378.jpg',
#  'img_04379.jpg',
#  'img_04400.jpg',
#  'img_04412.jpg',
#  'img_04431.jpg',
#  'img_04433.jpg',
#  'img_04436.jpg',
#  'img_04441.jpg',
#  'img_04446.jpg',
#  'img_04460.jpg',
#  'img_04466.jpg',
#  'img_04471.jpg',
#  'img_04474.jpg',
#  'img_04477.jpg',
#  'img_04480.jpg',
#  'img_04489.jpg',
#  'img_04490.jpg',
#  'img_04500.jpg',
#  'img_04504.jpg',
#  'img_04513.jpg',
#  'img_04517.jpg',
#  'img_04519.jpg',
#  'img_04524.jpg',
#  'img_04527.jpg',
#  'img_04528.jpg',
#  'img_04537.jpg',
#  'img_04542.jpg',
#  'img_04543.jpg',
#  'img_04545.jpg',
#  'img_04547.jpg',
#  'img_04552.jpg',
#  'img_04561.jpg',
#  'img_04567.jpg',
#  'img_04570.jpg',
#  'img_04572.jpg',
#  'img_04574.jpg',
#  'img_04578.jpg',
#  'img_04579.jpg',
#  'img_04583.jpg',
#  'img_04588.jpg',
#  'img_04589.jpg',
#  'img_04598.jpg',
#  'img_04609.jpg',
#  'img_04612.jpg',
#  'img_04630.jpg',
#  'img_04633.jpg',
#  'img_04635.jpg',
#  'img_04659.jpg',
#  'img_04660.jpg',
#  ...]

# %%
np.random.seed(7)

labels = []
img_data = []

label_map = dict(zip([i for i in os.listdir('../input/train') if not i=='.DS_Store'], range(8)))

for d in os.listdir('../input/train'):
    print("Processing {}...".format(d))
    if d == '.DS_Store':
        continue
    for f in os.listdir(os.path.join('../input/train', d)):
        if f == '.DS_Store': # add this line 
            continue # Add this line
        labels.append(label_map[d])
        im = load_img(os.path.join('../input/train', d, f))
        im_data = img_to_array(im)
        im_data.resize(64, 64, 3)
        img_data.append(im_data)
print("Unique number of labels:", len(set(labels)))
print("Number of images:", len(img_data))
print("Length of label map:", len(label_map))


def cnn():
    model = Sequential()
    model.add(Convolution2D(32,3,3, border_mode='same', input_shape=(64,64,3)))
    model.add(Activation('relu'))
    model.add(Convolution2D(32,3,3))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))
    
    model.add(Convolution2D(64,3,3, border_mode='same'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(256))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    
    model.add(Dense(8))
    model.add(Activation('softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model
# Out:
# Processing .DS_Store...
# Processing ALB...
# Processing BET...
# Processing DOL...
# Processing LAG...
# Processing NoF...
# Processing OTHER...
# Processing SHARK...
# Processing YFT...
# ('Unique number of labels:', 8)
# ('Number of images:', 3777)
# ('Length of label map:', 8)

# %%
X = np.array(img_data)
y = np.array(labels)

X = X.astype('float32')
y = y.astype('float32')
print("Data converted...")

X /= 255.

# class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y), y=y)

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# y_train = np_utils.to_categorical(y_train)
# y_test = np_utils.to_categorical(y_test)

# print(X_train.shape)
# print(X_test.shape)
# print(y_train.shape)
# print(y_test.shape)
y = np_utils.to_categorical(y)

model = cnn()
print("Model loaded...")
# model.fit(X_train, y_train, nb_epoch=10, batch_size=64, verbose=2)
model.fit(X, y, nb_epoch=10, batch_size=64, class_weight=None, verbose=2)

# preds = model.predict(X_test)
# print ("Log loss on hold-out set:", log_loss(y_test, preds))
# Out:
# Data converted...
# /Users/HUGO/anaconda2/envs/tensorflow/lib/python2.7/site-packages/keras/utils/np_utils.py:21: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   Y = np.zeros((len(y), nb_classes))
# /Users/HUGO/anaconda2/envs/tensorflow/lib/python2.7/site-packages/keras/utils/np_utils.py:23: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   Y[i, y[i]] = 1.
# Model loaded...
# Epoch 1/10
# 86s - loss: 1.6312 - acc: 0.4512
# Epoch 2/10
# 84s - loss: 1.5161 - acc: 0.4911
# Epoch 3/10
# 96s - loss: 1.3091 - acc: 0.5475
# Epoch 4/10
# 80s - loss: 1.2041 - acc: 0.5809
# Epoch 5/10
# 80s - loss: 1.0270 - acc: 0.6235
# Epoch 6/10
# 80s - loss: 0.9112 - acc: 0.6828
# Epoch 7/10
# 79s - loss: 0.8123 - acc: 0.7220
# Epoch 8/10
# 79s - loss: 0.7688 - acc: 0.7278
# Epoch 9/10
# 79s - loss: 0.6376 - acc: 0.7813
# Epoch 10/10
# 82s - loss: 0.6087 - acc: 0.7932
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-20-cc5d883e1e2e> in <module>()
#      33 test_imgs = []
#      34
# ---> 35 for fname in os.listdir('../input/test_stg1'):
#      36     if fname == '.DS_Store':
#      37         continue
#
# OSError: [Errno 2] No such file or directory: '../input/test_stg1'

# %%
test_im_names = []
test_imgs = []

for fname in os.listdir('../input/test_stg1'):
    if fname == '.DS_Store':
        continue
    test_im_names.append(fname)
    im = load_img(os.path.join('../input/test_stg1', fname))
    im_data = img_to_array(im)
    im_data.resize(64, 64, 3)
    test_imgs.append(im_data)
    
print("Number of images", len(test_imgs))
print("Image size:", test_imgs[0].shape)


X_test_final = np.array(test_imgs)
X_test_final.astype('float32')
X_test_final /= 255.
# Out:
# ('Number of images', 1000)
# ('Image size:', (64, 64, 3))

# %%
final_preds = model.predict(X_test_final)

prediction_df = pd.DataFrame(final_preds)
prediction_df.columns= ['ALB','BET','DOL','LAG','NoF','OTHER','SHARK','YFT']
prediction_df['image'] = test_im_names
prediction_df = prediction_df[['image','ALB','BET','DOL','LAG','NoF','OTHER','SHARK','YFT']]
prediction_df.to_csv('submission.csv', encoding='utf8', index=False)

print("Done!")
# Out:
# Done!
